# %%
pip install plotnine
# Out:
# ...
#   Using cached plotnine-0.14.5-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Using cached mizani-0.13.1-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# ...
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    ---------------- ----------------------- 0.5/1.3 MB 840.2 kB/s eta 0:00:01
#    ---------------- ----------------------- 0.5/1.3 MB 840.2 kB/s eta 0:00:01
#    ---------------- ----------------------- 0.5/1.3 MB 840.2 kB/s eta 0:00:01
# ...

# %%
from plotnine import ggplot, aes, geom_point

# %%
import pandas as pd

# %%
mov=pd.read_csv(r"C:\Users\hp\Desktop\Movies.csv")
mov
# Out:
#     Rank                       Movie Title Language Domestic Revenue (₹ Cr)  \
# 0      1                Pushpa 2: The Rule   Telugu                   1,200
# 1      2                     Kalki 2898 AD   Telugu                     680
# 2      3                           Stree 2    Hindi                     550
# 3      4          The Greatest of All Time    Tamil                     240
# 4      5                    Devara: Part 1   Telugu                     315
# 5      6                 Bhool Bhulaiyaa 3    Hindi                     358
# 6      7                     Singham Again    Hindi                     310
# 7      8                           Fighter    Hindi                     270
# 8      9                          Shaitaan    Hindi                     160
# 9     10                              Crew    Hindi                     123
# 10    11  Teri Baaton Mein Aisa Uljha Jiya    Hindi                     120
# ...

# %%
from plotnine import ggplot, aes, geom_col
ggplot(mov)

ggplot(mov) + aes(x=mov.Rank, y=mov['Budget (₹ Cr)'])+ geom_col()

# %%
ggplot(mov) + aes(x=mov.Rank, y=mov['Domestic Revenue (₹ Cr)'])+ geom_col()

# %%
ggplot(mov) + aes(x=mov.Rank, y=mov['International Revenue (₹ Cr)'])+ geom_col()

# %%
ggplot(mov) + aes(x=mov['Movie Title'], y=mov['Budget (₹ Cr)'])+ geom_col()

# %%
from plotnine import ggplot, aes, geom_histogram



ggplot(mov) + aes(x=mov['Runtime']) + geom_histogram(bins=15)

# %%
ggplot(mov) + aes(x=mov['Language']) + geom_histogram(bins=5)

# %%
ggplot(mov) + aes(x=mov.Rank, y=mov['International Revenue (₹ Cr)']) + geom_point()

# %%
ggplot(mov) + aes(x=mov['Rank'], y=mov['Budget (₹ Cr)']) + geom_point()

# %%
ggplot(mov) + aes(x=mov['Rank'], y=mov['Runtime']) + geom_point()

# %%
from plotnine import ggplot, aes, geom_line

ggplot(mov) + aes(x=mov.Rank, y=mov['Budget (₹ Cr)']) + geom_line()

# %%
ggplot(mov) + aes(x=mov.Rank, y=mov['International Revenue (₹ Cr)']) + geom_line()
