# %%
import pandas as pd

# %%
mov=pd.read_csv(r"C:\Users\hp\Desktop\Movies.csv")
mov
# Out:
#     Rank                       Movie Title Language Domestic Revenue (₹ Cr)  \
# 0      1                Pushpa 2: The Rule   Telugu                   1,200
# 1      2                     Kalki 2898 AD   Telugu                     680
# 2      3                           Stree 2    Hindi                     550
# 3      4          The Greatest of All Time    Tamil                     240
# 4      5                    Devara: Part 1   Telugu                     315
# 5      6                 Bhool Bhulaiyaa 3    Hindi                     358
# 6      7                     Singham Again    Hindi                     310
# 7      8                           Fighter    Hindi                     270
# 8      9                          Shaitaan    Hindi                     160
# 9     10                              Crew    Hindi                     123
# 10    11  Teri Baaton Mein Aisa Uljha Jiya    Hindi                     120
# ...

# %%
mov.head()
# Out:
#    Rank               Movie Title Language Domestic Revenue (₹ Cr)  \
# 0     1        Pushpa 2: The Rule   Telugu                   1,200
# 1     2             Kalki 2898 AD   Telugu                     680
# 2     3                   Stree 2    Hindi                     550
# 3     4  The Greatest of All Time    Tamil                     240
# 4     5            Devara: Part 1   Telugu                     315
#
#    International Revenue (₹ Cr) Total Revenue (₹ Cr)             Genre  \
# 0                           624                1,824  Action, Thriller
# 1                           362          1,042–1,200   Sci-Fi, Fantasy
# 2                           324               874.58    Horror, Comedy
# 3                           200           440–457.12  Drama, Biography
# 4                            88           403.83–521     Action, Drama
#
#         Director Release Date  Budget (₹ Cr)  \
# 0        Sukumar    15-Aug-24            400
# ...

# %%
mov.sample(3)
# Out:
#     Rank                       Movie Title Language Domestic Revenue (₹ Cr)  \
# 10    11  Teri Baaton Mein Aisa Uljha Jiya    Hindi                     120
# 6      7                     Singham Again    Hindi                     310
# 12    13                          Bad Newz    Hindi                      92
#
#     International Revenue (₹ Cr) Total Revenue (₹ Cr)            Genre  \
# 10                            13               133.64  Romantic, Drama
# 6                             79               389.64    Action, Crime
# 12                            23               115.74         Thriller
#
#                 Director Release Date  Budget (₹ Cr)  \
# 10         Laxman Utekar    20-Sep-24             40
# 6           Rohit Shetty    15-Aug-24            200
# 12  Vikramaditya Motwane    12-Jul-24             70
#
#                       Main Cast  Runtime   Music Composer
# 10  Vicky Kaushal, Katrina Kaif  150 min      A.R. Rahman
# ...

# %%
mov.shape
# Out:
# (15, 13)

# %%
mov['Movie Title']
# Out:
# 0                   Pushpa 2: The Rule
# 1                        Kalki 2898 AD
# 2                              Stree 2
# 3             The Greatest of All Time
# 4                       Devara: Part 1
# 5                    Bhool Bhulaiyaa 3
# 6                        Singham Again
# 7                              Fighter
# 8                             Shaitaan
# 9                                 Crew
# 10    Teri Baaton Mein Aisa Uljha Jiya
# 11                              Munjya
# 12                            Bad Newz
# 13                         Article 370
# 14                           Vettaiyan
# Name: Movie Title, dtype: object

# %%
mov['Budget (₹ Cr)'].max()
# Out:
# 600

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Rank                          15 non-null     int64
#  1   Movie Title                   15 non-null     object
#  2   Language                      15 non-null     object
#  3   Domestic Revenue (₹ Cr)       15 non-null     object
#  4   International Revenue (₹ Cr)  15 non-null     int64
#  5   Total Revenue (₹ Cr)          15 non-null     object
#  6   Genre                         15 non-null     object
#  7   Director                      15 non-null     object
#  8   Release Date                  15 non-null     object
#  9   Budget (₹ Cr)                 15 non-null     int64
#  10  Main Cast                     15 non-null     object
#  11  Runtime                       15 non-null     object
# ...

# %%
mov.describe()
# Out:
#             Rank  International Revenue (₹ Cr)  Budget (₹ Cr)
# count  15.000000                     15.000000      15.000000
# mean    8.000000                    133.266667     169.333333
# std     4.472136                    174.938955     155.722586
# min     1.000000                     13.000000      40.000000
# 25%     4.500000                     24.000000      65.000000
# 50%     8.000000                     65.000000     100.000000
# 75%    11.500000                    144.000000     225.000000
# max    15.000000                    624.000000     600.000000

# %%
mov['Budget (₹ Cr)'].max()
# Out:
# 600

# %%
mov['Budget (₹ Cr)'].min()
# Out:
# 40

# %%
mov['International Revenue (₹ Cr)'].max()
# Out:
# 624

# %%
mov['International Revenue (₹ Cr)'].min()
# Out:
# 13

# %%
mov[mov.Runtime=='160 min']
# Out:
#     Rank               Movie Title Language Domestic Revenue (₹ Cr)  \
# 3      4  The Greatest of All Time    Tamil                     240
# 7      8                   Fighter    Hindi                     270
# 12    13                  Bad Newz    Hindi                      92
#
#     International Revenue (₹ Cr) Total Revenue (₹ Cr)             Genre  \
# 3                            200           440–457.12  Drama, Biography
# 7                             74               344.46     Action, Drama
# 12                            23               115.74          Thriller
#
#                 Director Release Date  Budget (₹ Cr)  \
# 3          Sudha Kongara    17-Nov-24            100
# 7        Siddharth Anand    26-Jan-24            250
# 12  Vikramaditya Motwane    12-Jul-24             70
#
#                            Main Cast  Runtime          Music Composer
# 3   Vijay Sethupathi, Keerthy Suresh  160 min             A.R. Rahman
# ...

# %%
mov[mov.Genre=='Action, Drama']
# Out:
#     Rank     Movie Title Language Domestic Revenue (₹ Cr)  \
# 4      5  Devara: Part 1   Telugu                     315
# 7      8         Fighter    Hindi                     270
# 14    15       Vettaiyan    Tamil                     123
#
#     International Revenue (₹ Cr) Total Revenue (₹ Cr)          Genre  \
# 4                             88           403.83–521  Action, Drama
# 7                             74               344.46  Action, Drama
# 14                            20              143.243  Action, Drama
#
#             Director Release Date  Budget (₹ Cr)  \
# 4      Koratala Siva    25-Dec-24            250
# 7    Siddharth Anand    26-Jan-24            250
# 14  Lokesh Kanagaraj    18-Oct-24            150
#
#                            Main Cast  Runtime          Music Composer
# 4              Jr NTR, Saif Ali Khan  165 min     Anirudh Ravichander
# 7   Hrithik Roshan, Deepika Padukone  160 min  Lijo George, DJ Chetas
# ...

# %%
mov.drop(['Genre','Rank'],axis=1)
# Out:
#                          Movie Title Language Domestic Revenue (₹ Cr)  \
# 0                 Pushpa 2: The Rule   Telugu                   1,200
# 1                      Kalki 2898 AD   Telugu                     680
# 2                            Stree 2    Hindi                     550
# 3           The Greatest of All Time    Tamil                     240
# 4                     Devara: Part 1   Telugu                     315
# 5                  Bhool Bhulaiyaa 3    Hindi                     358
# 6                      Singham Again    Hindi                     310
# 7                            Fighter    Hindi                     270
# 8                           Shaitaan    Hindi                     160
# 9                               Crew    Hindi                     123
# 10  Teri Baaton Mein Aisa Uljha Jiya    Hindi                     120
# 11                            Munjya    Hindi                     115
# ...

# %%
mov[['Rank','Movie Title','Total Revenue (₹ Cr)']]
# Out:
#     Rank                       Movie Title Total Revenue (₹ Cr)
# 0      1                Pushpa 2: The Rule                1,824
# 1      2                     Kalki 2898 AD          1,042–1,200
# 2      3                           Stree 2               874.58
# 3      4          The Greatest of All Time           440–457.12
# 4      5                    Devara: Part 1           403.83–521
# 5      6                 Bhool Bhulaiyaa 3               423.85
# 6      7                     Singham Again               389.64
# 7      8                           Fighter               344.46
# 8      9                          Shaitaan               211.06
# 9     10                              Crew               157.08
# 10    11  Teri Baaton Mein Aisa Uljha Jiya               133.64
# 11    12                            Munjya               132.13
# 12    13                          Bad Newz               115.74
# 13    14                       Article 370               110.57
# ...

# %%
mov.sort_values('International Revenue (₹ Cr)')
# Out:
#     Rank                       Movie Title Language Domestic Revenue (₹ Cr)  \
# 10    11  Teri Baaton Mein Aisa Uljha Jiya    Hindi                     120
# 11    12                            Munjya    Hindi                     115
# 14    15                         Vettaiyan    Tamil                     123
# 12    13                          Bad Newz    Hindi                      92
# 13    14                       Article 370    Hindi                      85
# 9     10                              Crew    Hindi                     123
# 8      9                          Shaitaan    Hindi                     160
# 5      6                 Bhool Bhulaiyaa 3    Hindi                     358
# 7      8                           Fighter    Hindi                     270
# 6      7                     Singham Again    Hindi                     310
# 4      5                    Devara: Part 1   Telugu                     315
# ...

# %%
mov['Total Revenue (₹ Cr)'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           1,824
# 1     1,042–1,200
# 2          874.58
# 3      440–457.12
# 4      403.83–521
# 5          423.85
# 6          389.64
# 7          344.46
# 8          211.06
# 9          157.08
# 10         133.64
# 11         132.13
# 12         115.74
# 13         110.57
# 14        143.243
# Name: Total Revenue (₹ Cr), dtype: object>
