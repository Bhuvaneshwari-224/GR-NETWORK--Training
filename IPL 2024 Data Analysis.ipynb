# %%
import pandas as pd

# %%
ipl=pd.read_csv(r"C:\Users\hp\Downloads\archive (2)\IPL_PLAYERS.csv")
ipl
# Out:
#                  PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 0   Avanish Rao Aravelly      Indian  Wicket-Keeper     2000000  CSK
# 1      Mustafizur Rahman    Overseas         Bowler    20000000  CSK
# 2         Daryl Mitchell    Overseas    All-Rounder   140000000  CSK
# 3           Sameer Rizvi      Indian         Batter    84000000  CSK
# 4        Rachin Ravindra    Overseas    All-Rounder    18000000  CSK
# ..                   ...         ...            ...         ...  ...
# 67           Akash Singh      Indian         Bowler     2000000   SH
# 68        Jaydev Unadkat      Indian         Bowler    16000000   SH
# 69     Wanindu Hasaranga    Overseas    All-Rounder    15000000   SH
# 70           Pat Cummins    Overseas    All-Rounder   205000000   SH
# 71           Travis Head    Overseas         Batter    68000000   SH
#
# [72 rows x 5 columns]

# %%
ipl.columns
# Out:
# Index(['PLAYERS', 'NATIONALITY', 'TYPE', 'PRICE PAID', 'TEAM'], dtype='object')

# %%
ipl.PLAYERS
# Out:
# 0     Avanish Rao Aravelly
# 1        Mustafizur Rahman
# 2           Daryl Mitchell
# 3             Sameer Rizvi
# 4          Rachin Ravindra
#               ...
# 67             Akash Singh
# 68          Jaydev Unadkat
# 69       Wanindu Hasaranga
# 70             Pat Cummins
# 71             Travis Head
# Name: PLAYERS, Length: 72, dtype: object

# %%
ipl.PLAYERS.unique()
# Out:
# array(['Avanish Rao Aravelly', 'Mustafizur Rahman', 'Daryl Mitchell',
#        'Sameer Rizvi', 'Rachin Ravindra', 'Shardul Thakur', 'Ricky Bhui',
#        'Sumit Kumar', 'Swastik Chhikara', 'Jhye Richardson', 'Shai Hope',
#        'Rasikh Dar', 'Kumar Kushagra', 'Tristan Stubbs', 'Harry Brook',
#        'Kartik Tyagi', 'Spencer Johnson', 'Manav Suthar', 'Robin Minz',
#        'Sushant Mishra', 'Azmatullah Omarzai', 'Shahrukh Khan',
#        'Umesh Yadav', 'Mujeeb Rahman', 'Manish Pandey', 'Gus Atkinson',
#        'Angkrish Raghuvanshi', 'Mitchell Starc', 'Sherfane Rutherford',
#        'Ramandeep Singh', 'K.S. Bharat', 'Chetan Sakariya',
#        'Sakib Hussain', 'Ashton Turner', 'David Willey', 'M. Siddharth',
#        'Shivam Mavi', 'Arshin Kulkarni', 'Mohd. Arshad Khan',
#        'Dilshan Madushanka', 'Shreyas Gopal', 'Shivalik Sharma',
#        'Anshul Kamboj', 'Mohammad Nabi', 'Naman Dhir', 'Nuwan Thushara',
#        'Gerald Coetzee', 'Chris Woakes', 'Tanay Thyagarajann',
# ...

# %%
ipl.head()
# Out:
#                 PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 0  Avanish Rao Aravelly      Indian  Wicket-Keeper     2000000  CSK
# 1     Mustafizur Rahman    Overseas         Bowler    20000000  CSK
# 2        Daryl Mitchell    Overseas    All-Rounder   140000000  CSK
# 3          Sameer Rizvi      Indian         Batter    84000000  CSK
# 4       Rachin Ravindra    Overseas    All-Rounder    18000000  CSK

# %%
ipl.tail()
# Out:
#               PLAYERS NATIONALITY         TYPE  PRICE PAID TEAM
# 67        Akash Singh      Indian       Bowler     2000000   SH
# 68     Jaydev Unadkat      Indian       Bowler    16000000   SH
# 69  Wanindu Hasaranga    Overseas  All-Rounder    15000000   SH
# 70        Pat Cummins    Overseas  All-Rounder   205000000   SH
# 71        Travis Head    Overseas       Batter    68000000   SH

# %%
ipl.sample()
# Out:
#                PLAYERS NATIONALITY         TYPE  PRICE PAID TEAM
# 48  Tanay Thyagarajann      Indian  All-Rounder     2000000   PK

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYERS      72 non-null     object
#  1   NATIONALITY  72 non-null     object
#  2   TYPE         72 non-null     object
#  3   PRICE PAID   72 non-null     int64
#  4   TEAM         72 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.9+ KB

# %%
ipl.describe()
# Out:
#          PRICE PAID
# count  7.200000e+01
# mean   3.200694e+07
# std    4.659788e+07
# min    2.000000e+06
# 25%    2.000000e+06
# 50%    1.250000e+07
# 75%    4.850000e+07
# max    2.475000e+08

# %%
ipl.shape
# Out:
# (72, 5)

# %%
ipl.sample()
# Out:
#       PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 10  Shai Hope    Overseas  Wicket-Keeper     7500000   DC

# %%
ipl.notnull().sum()
# Out:
# PLAYERS        72
# NATIONALITY    72
# TYPE           72
# PRICE PAID     72
# TEAM           72
# dtype: int64

# %%
ipl.style.set_caption("PLAYERS LIST")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d5499">
#   <caption>PLAYERS LIST</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5499_level0_col0" class="col_heading level0 col0" >PLAYERS</th>
#       <th id="T_d5499_level0_col1" class="col_heading level0 col1" >NATIONALITY</th>
#       <th id="T_d5499_level0_col2" class="col_heading level0 col2" >TYPE</th>
#       <th id="T_d5499_level0_col3" class="col_heading level0 col3" >PRICE PAID</th>
#       <th id="T_d5499_level0_col4" class="col_heading level0 col4" >TEAM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5499_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5499_row0_col0" class="data row0 col0" >Avanish Rao Aravelly</td>
#       <td id="T_d5499_row0_col1" class="data row0 col1" >Indian</td>
#       <td id="T_d5499_row0_col2" class="data row0 col2" >Wicket-Keeper</td>
# ...

# %%
ipl.TEAM.unique()
# Out:
# array(['CSK', 'DC', 'GT', 'KKR', 'LSG', 'MI', 'PK', 'RR', 'RCB', 'SH'],
#       dtype=object)

# %%
Teams=['CSK','DC','GT','KKR','LSG','MI','PK','RR','RCB','SH']

# %%
Teams
# Out:
# ['CSK', 'DC', 'GT', 'KKR', 'LSG', 'MI', 'PK', 'RR', 'RCB', 'SH']

# %%
ipl[ipl.TEAM=='CSK']
# Out:
#                 PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 0  Avanish Rao Aravelly      Indian  Wicket-Keeper     2000000  CSK
# 1     Mustafizur Rahman    Overseas         Bowler    20000000  CSK
# 2        Daryl Mitchell    Overseas    All-Rounder   140000000  CSK
# 3          Sameer Rizvi      Indian         Batter    84000000  CSK
# 4       Rachin Ravindra    Overseas    All-Rounder    18000000  CSK
# 5        Shardul Thakur      Indian    All-Rounder    40000000  CSK

# %%
ipl[ipl.TEAM=="SH"]
# Out:
#                    PLAYERS NATIONALITY         TYPE  PRICE PAID TEAM
# 66  Jhathavedh Subramanyan      Indian       Bowler     2000000   SH
# 67             Akash Singh      Indian       Bowler     2000000   SH
# 68          Jaydev Unadkat      Indian       Bowler    16000000   SH
# 69       Wanindu Hasaranga    Overseas  All-Rounder    15000000   SH
# 70             Pat Cummins    Overseas  All-Rounder   205000000   SH
# 71             Travis Head    Overseas       Batter    68000000   SH

# %%
ipl[ipl['PRICE PAID']==2000000]
# Out:
#                     PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 0      Avanish Rao Aravelly      Indian  Wicket-Keeper     2000000  CSK
# 6                Ricky Bhui      Indian  Wicket-Keeper     2000000   DC
# 8          Swastik Chhikara      Indian         Batter     2000000   DC
# 11               Rasikh Dar      Indian         Bowler     2000000   DC
# 17             Manav Suthar      Indian         Bowler     2000000   GT
# 26     Angkrish Raghuvanshi      Indian         Batter     2000000  KKR
# 29          Ramandeep Singh      Indian    All-Rounder     2000000  KKR
# 32            Sakib Hussain      Indian         Bowler     2000000  KKR
# 37          Arshin Kulkarni      Indian    All-Rounder     2000000  LSG
# 38        Mohd. Arshad Khan      Indian    All-Rounder     2000000  LSG
# 40            Shreyas Gopal      Indian         Bowler     2000000   MI
# 41          Shivalik Sharma      Indian    All-Rounder     2000000   MI
# ...

# %%
ipl[ipl['PRICE PAID'] >= 100000000]
# Out:
#             PLAYERS NATIONALITY         TYPE  PRICE PAID TEAM
# 2    Daryl Mitchell    Overseas  All-Rounder   140000000  CSK
# 16  Spencer Johnson    Overseas       Bowler   100000000   GT
# 27   Mitchell Starc    Overseas       Bowler   247500000  KKR
# 54    Harshal Patel      Indian  All-Rounder   117500000   PK
# 63   Alzarri Joseph    Overseas       Bowler   115000000  RCB
# 70      Pat Cummins    Overseas  All-Rounder   205000000   SH

# %%
ipl[ipl['PRICE PAID'] <=2000000]
# Out:
#                     PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 0      Avanish Rao Aravelly      Indian  Wicket-Keeper     2000000  CSK
# 6                Ricky Bhui      Indian  Wicket-Keeper     2000000   DC
# 8          Swastik Chhikara      Indian         Batter     2000000   DC
# 11               Rasikh Dar      Indian         Bowler     2000000   DC
# 17             Manav Suthar      Indian         Bowler     2000000   GT
# 26     Angkrish Raghuvanshi      Indian         Batter     2000000  KKR
# 29          Ramandeep Singh      Indian    All-Rounder     2000000  KKR
# 32            Sakib Hussain      Indian         Bowler     2000000  KKR
# 37          Arshin Kulkarni      Indian    All-Rounder     2000000  LSG
# 38        Mohd. Arshad Khan      Indian    All-Rounder     2000000  LSG
# 40            Shreyas Gopal      Indian         Bowler     2000000   MI
# 41          Shivalik Sharma      Indian    All-Rounder     2000000   MI
# ...

# %%
ipl[(ipl.NATIONALITY=='Indian') & (ipl.TEAM=='CSK')]
# Out:
#                 PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 0  Avanish Rao Aravelly      Indian  Wicket-Keeper     2000000  CSK
# 3          Sameer Rizvi      Indian         Batter    84000000  CSK
# 5        Shardul Thakur      Indian    All-Rounder    40000000  CSK

# %%
ipl[(ipl.TYPE=='Batter') | (ipl.TEAM=='SH')]
# Out:
#                    PLAYERS NATIONALITY         TYPE  PRICE PAID TEAM
# 3             Sameer Rizvi      Indian       Batter    84000000  CSK
# 8         Swastik Chhikara      Indian       Batter     2000000   DC
# 14             Harry Brook    Overseas       Batter    40000000   DC
# 24           Manish Pandey      Indian       Batter     5000000  KKR
# 26    Angkrish Raghuvanshi      Indian       Batter     2000000  KKR
# 28     Sherfane Rutherford    Overseas       Batter    15000000  KKR
# 33           Ashton Turner    Overseas       Batter    10000000  LSG
# 51          Shashank Singh      Indian       Batter     2000000   PK
# 52           Rilee Rossouw    Overseas       Batter    80000000   PK
# 55           Shubham Dubey      Indian       Batter    58000000   RR
# 56           Rovman Powell    Overseas       Batter    74000000   RR
# 62          Saurav Chuahan      Indian       Batter     2000000  RCB
# 66  Jhathavedh Subramanyan      Indian       Bowler     2000000   SH
# ...

# %%
ipl[(ipl.NATIONALITY=="Overseas") & ~(ipl.TEAM=="CSK")]
# Out:
#                 PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 9       Jhye Richardson    Overseas         Bowler    50000000   DC
# 10            Shai Hope    Overseas  Wicket-Keeper     7500000   DC
# 13       Tristan Stubbs    Overseas  Wicket-Keeper     5000000   DC
# 14          Harry Brook    Overseas         Batter    40000000   DC
# 16      Spencer Johnson    Overseas         Bowler   100000000   GT
# 20   Azmatullah Omarzai    Overseas    All-Rounder     5000000   GT
# 23        Mujeeb Rahman    Overseas         Bowler    20000000  KKR
# 25         Gus Atkinson    Overseas         Bowler    10000000  KKR
# 27       Mitchell Starc    Overseas         Bowler   247500000  KKR
# 28  Sherfane Rutherford    Overseas         Batter    15000000  KKR
# 33        Ashton Turner    Overseas         Batter    10000000  LSG
# 34         David Willey    Overseas    All-Rounder    20000000  LSG
# 39   Dilshan Madushanka    Overseas         Bowler    46000000   MI
# ...

# %%
ipl[(ipl.NATIONALITY=='Indian') & (ipl.TEAM=='KKR') & (ipl["PRICE PAID"] <= 20000000)]
# Out:
#                  PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 24         Manish Pandey      Indian         Batter     5000000  KKR
# 26  Angkrish Raghuvanshi      Indian         Batter     2000000  KKR
# 29       Ramandeep Singh      Indian    All-Rounder     2000000  KKR
# 30           K.S. Bharat      Indian  Wicket-Keeper     5000000  KKR
# 31       Chetan Sakariya      Indian         Bowler     5000000  KKR
# 32         Sakib Hussain      Indian         Bowler     2000000  KKR

# %%
Col=ipl[(ipl.NATIONALITY=='Indian') & (ipl.TEAM=='KKR') & (ipl["PRICE PAID"] <= 20000000)]

# %%
Col[['NATIONALITY','PRICE PAID','TEAM']]
# Out:
#    NATIONALITY  PRICE PAID TEAM
# 24      Indian     5000000  KKR
# 26      Indian     2000000  KKR
# 29      Indian     2000000  KKR
# 30      Indian     5000000  KKR
# 31      Indian     5000000  KKR
# 32      Indian     2000000  KKR

# %%
ipl.PLAYERS.sort_values().unique()
# Out:
# array(['Abid Mushtaq', 'Akash Singh', 'Alzarri Joseph',
#        'Angkrish Raghuvanshi', 'Anshul Kamboj', 'Arshin Kulkarni',
#        'Ashton Turner', 'Ashutosh Sharma', 'Avanish Rao Aravelly',
#        'Azmatullah Omarzai', 'Chetan Sakariya', 'Chris Woakes',
#        'Daryl Mitchell', 'David Willey', 'Dilshan Madushanka',
#        'Gerald Coetzee', 'Gus Atkinson', 'Harry Brook', 'Harshal Patel',
#        'Jaydev Unadkat', 'Jhathavedh Subramanyan', 'Jhye Richardson',
#        'K.S. Bharat', 'Kartik Tyagi', 'Kumar Kushagra', 'Lockie Ferguson',
#        'M. Siddharth', 'Manav Suthar', 'Manish Pandey', 'Mitchell Starc',
#        'Mohammad Nabi', 'Mohd. Arshad Khan', 'Mujeeb Rahman',
#        'Mustafizur Rahman', 'Naman Dhir', 'Nandre Burger',
#        'Nuwan Thushara', 'Pat Cummins', 'Prince Choudhary',
#        'Rachin Ravindra', 'Ramandeep Singh', 'Rasikh Dar', 'Ricky Bhui',
#        'Rilee Rossouw', 'Robin Minz', 'Rovman Powell', 'Sakib Hussain',
# ...

# %%
ipl.sort_values('PLAYERS')
# Out:
#                     PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 57             Abid Mushtaq      Indian    All-Rounder     2000000   RR
# 67              Akash Singh      Indian         Bowler     2000000   SH
# 63           Alzarri Joseph    Overseas         Bowler   115000000  RCB
# 26     Angkrish Raghuvanshi      Indian         Batter     2000000  KKR
# 42            Anshul Kamboj      Indian    All-Rounder     2000000   MI
# ..                      ...         ...            ...         ...  ...
# 13           Tristan Stubbs    Overseas  Wicket-Keeper     5000000   DC
# 22              Umesh Yadav      Indian         Bowler    58000000   GT
# 49  Vishwanath Pratap Singh      Indian    All-Rounder     2000000   PK
# 69        Wanindu Hasaranga    Overseas    All-Rounder    15000000   SH
# 65               Yash Dayal      Indian         Bowler    50000000  RCB
#
# [72 rows x 5 columns]

# %%
ipl.sort_values("TYPE",ascending=False)
# Out:
#                     PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 0      Avanish Rao Aravelly      Indian  Wicket-Keeper     2000000  CSK
# 59       Tom Kohler-Cadmore    Overseas  Wicket-Keeper     4000000   RR
# 30              K.S. Bharat      Indian  Wicket-Keeper     5000000  KKR
# 18               Robin Minz      Indian  Wicket-Keeper    36000000   GT
# 13           Tristan Stubbs    Overseas  Wicket-Keeper     5000000   DC
# ..                      ...         ...            ...         ...  ...
# 50          Ashutosh Sharma      Indian    All-Rounder     2000000   PK
# 43            Mohammad Nabi    Overseas    All-Rounder    15000000   MI
# 48       Tanay Thyagarajann      Indian    All-Rounder     2000000   PK
# 47             Chris Woakes    Overseas    All-Rounder    42000000   PK
# 49  Vishwanath Pratap Singh      Indian    All-Rounder     2000000   PK
#
# [72 rows x 5 columns]

# %%
ipl.TEAM.str.lower()
# Out:
# 0     csk
# 1     csk
# 2     csk
# 3     csk
# 4     csk
#      ...
# 67     sh
# 68     sh
# 69     sh
# 70     sh
# 71     sh
# Name: TEAM, Length: 72, dtype: object

# %%
ipl.TEAM.str.upper()
# Out:
# 0     CSK
# 1     CSK
# 2     CSK
# 3     CSK
# 4     CSK
#      ...
# 67     SH
# 68     SH
# 69     SH
# 70     SH
# 71     SH
# Name: TEAM, Length: 72, dtype: object

# %%
ipl.TEAM.str.capitalize()
# Out:
# 0     Csk
# 1     Csk
# 2     Csk
# 3     Csk
# 4     Csk
#      ...
# 67     Sh
# 68     Sh
# 69     Sh
# 70     Sh
# 71     Sh
# Name: TEAM, Length: 72, dtype: object

# %%
ipl.PLAYERS.str.contains('Chris Woakes')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# Name: PLAYERS, Length: 72, dtype: bool

# %%
ipl.NATIONALITY.str.contains("Indian")
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 67     True
# 68     True
# 69    False
# 70    False
# 71    False
# Name: NATIONALITY, Length: 72, dtype: bool

# %%
ipl.sort_values(by=["PLAYERS","NATIONALITY"])
# Out:
#                     PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 57             Abid Mushtaq      Indian    All-Rounder     2000000   RR
# 67              Akash Singh      Indian         Bowler     2000000   SH
# 63           Alzarri Joseph    Overseas         Bowler   115000000  RCB
# 26     Angkrish Raghuvanshi      Indian         Batter     2000000  KKR
# 42            Anshul Kamboj      Indian    All-Rounder     2000000   MI
# ..                      ...         ...            ...         ...  ...
# 13           Tristan Stubbs    Overseas  Wicket-Keeper     5000000   DC
# 22              Umesh Yadav      Indian         Bowler    58000000   GT
# 49  Vishwanath Pratap Singh      Indian    All-Rounder     2000000   PK
# 69        Wanindu Hasaranga    Overseas    All-Rounder    15000000   SH
# 65               Yash Dayal      Indian         Bowler    50000000  RCB
#
# [72 rows x 5 columns]

# %%
ipl.sort_values(by=["PLAYERS","NATIONALITY"],ascending=[False,True])
# Out:
#                     PLAYERS NATIONALITY           TYPE  PRICE PAID TEAM
# 65               Yash Dayal      Indian         Bowler    50000000  RCB
# 69        Wanindu Hasaranga    Overseas    All-Rounder    15000000   SH
# 49  Vishwanath Pratap Singh      Indian    All-Rounder     2000000   PK
# 22              Umesh Yadav      Indian         Bowler    58000000   GT
# 13           Tristan Stubbs    Overseas  Wicket-Keeper     5000000   DC
# ..                      ...         ...            ...         ...  ...
# 42            Anshul Kamboj      Indian    All-Rounder     2000000   MI
# 26     Angkrish Raghuvanshi      Indian         Batter     2000000  KKR
# 63           Alzarri Joseph    Overseas         Bowler   115000000  RCB
# 67              Akash Singh      Indian         Bowler     2000000   SH
# 57             Abid Mushtaq      Indian    All-Rounder     2000000   RR
#
# [72 rows x 5 columns]
