# %%
import pandas as pd

# %%
final=pd.read_csv(r"C:\Users\hp\Desktop\IPL 2011 Final.csv")

# %%
final
# Out:
#                           TEAMS             BATTER  RUNS  BALLS  4s  6s  \
# 0           Chennai Super Kings     Michael Hussey    63     45   3   3
# 1           Chennai Super Kings       Murali Vijay    95     52   4   6
# 2           Chennai Super Kings           MS Dhoni    22     13   0   2
# 3           Chennai Super Kings       Suresh Raina     8      5   0   1
# 4           Chennai Super Kings       Albie Morkel     2      4   0   0
# 5           Chennai Super Kings        S Badrinath     0      0   0   0
# 6           Chennai Super Kings       Dwayne Bravo     6      1   0   1
# 7   Royal Challengers Bangalore     Mayank Agarwal    10      5   2   0
# 8   Royal Challengers Bangalore        Chris Gayle     0      3   0   0
# 9   Royal Challengers Bangalore        Virat Kohli    35     32   1   1
# 10  Royal Challengers Bangalore     AB de Villiers    18     12   3   0
# 11  Royal Challengers Bangalore    Luke Pomersbach     2      3   0   0
# ...

# %%
final.shape
# Out:
# (17, 9)

# %%
final.BATTER.unique()
# Out:
# array(['Michael Hussey', 'Murali Vijay', 'MS Dhoni', 'Suresh Raina',
#        'Albie Morkel', 'S Badrinath', 'Dwayne Bravo', 'Mayank Agarwal',
#        'Chris Gayle', 'Virat Kohli', 'AB de Villiers', 'Luke Pomersbach',
#        'Saurabh Tiwary', 'Daniel Vettori', 'Abhimanyu Mithun ',
#        'Zaheer Khan', 'JS Mohammad'], dtype=object)

# %%
final['DID NOT BAT'].unique()
# Out:
# array(['Wriddhiman Saha', 'Ravichandran Ashwin', 'Shadab Jakati', 'Doug',
#        'Bollinger', nan, 'Sreenath Aravind'], dtype=object)

# %%
final[final.TEAMS=='Chennai Super Kings']
# Out:
#                  TEAMS          BATTER  RUNS  BALLS  4s  6s      SR  EXTRAS  \
# 0  Chennai Super Kings  Michael Hussey    63     45   3   3  140.00     9.0
# 1  Chennai Super Kings    Murali Vijay    95     52   4   6  182.69     NaN
# 2  Chennai Super Kings        MS Dhoni    22     13   0   2  169.23     NaN
# 3  Chennai Super Kings    Suresh Raina     8      5   0   1  160.00     NaN
# 4  Chennai Super Kings    Albie Morkel     2      4   0   0   50.00     NaN
# 5  Chennai Super Kings     S Badrinath     0      0   0   0    0.00     NaN
# 6  Chennai Super Kings    Dwayne Bravo     6      1   0   1  600.00     NaN
#
#            DID NOT BAT
# 0      Wriddhiman Saha
# 1  Ravichandran Ashwin
# 2        Shadab Jakati
# 3                 Doug
# 4            Bollinger
# 5                  NaN
# 6                  NaN

# %%
final.info
# Out:
# <bound method DataFrame.info of                           TEAMS             BATTER  RUNS  BALLS  4s  6s  \
# 0           Chennai Super Kings     Michael Hussey    63     45   3   3
# 1           Chennai Super Kings       Murali Vijay    95     52   4   6
# 2           Chennai Super Kings           MS Dhoni    22     13   0   2
# 3           Chennai Super Kings       Suresh Raina     8      5   0   1
# 4           Chennai Super Kings       Albie Morkel     2      4   0   0
# 5           Chennai Super Kings        S Badrinath     0      0   0   0
# 6           Chennai Super Kings       Dwayne Bravo     6      1   0   1
# 7   Royal Challengers Bangalore     Mayank Agarwal    10      5   2   0
# 8   Royal Challengers Bangalore        Chris Gayle     0      3   0   0
# 9   Royal Challengers Bangalore        Virat Kohli    35     32   1   1
# 10  Royal Challengers Bangalore     AB de Villiers    18     12   3   0
# 11  Royal Challengers Bangalore    Luke Pomersbach     2      3   0   0
# ...

# %%
final.describe()
# Out:
#             RUNS      BALLS         4s         6s          SR   EXTRAS
# count  17.000000  17.000000  17.000000  17.000000   17.000000  2.00000
# mean   19.823529  14.176471   1.058824   1.000000  134.617647  7.50000
# std    26.082167  16.584011   1.344925   1.658312  135.687941  2.12132
# min     0.000000   0.000000   0.000000   0.000000    0.000000  6.00000
# 25%     2.000000   3.000000   0.000000   0.000000   66.670000  6.75000
# 50%    10.000000   5.000000   0.000000   0.000000  123.530000  7.50000
# 75%    22.000000  21.000000   2.000000   1.000000  160.000000  8.25000
# max    95.000000  52.000000   4.000000   6.000000  600.000000  9.00000

# %%
final.style.set_caption("FINAL SCORE CARD")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f95cb">
#   <caption>FINAL SCORE CARD</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f95cb_level0_col0" class="col_heading level0 col0" >TEAMS</th>
#       <th id="T_f95cb_level0_col1" class="col_heading level0 col1" >BATTER</th>
#       <th id="T_f95cb_level0_col2" class="col_heading level0 col2" >RUNS</th>
#       <th id="T_f95cb_level0_col3" class="col_heading level0 col3" >BALLS</th>
#       <th id="T_f95cb_level0_col4" class="col_heading level0 col4" >4s</th>
#       <th id="T_f95cb_level0_col5" class="col_heading level0 col5" >6s</th>
#       <th id="T_f95cb_level0_col6" class="col_heading level0 col6" >SR</th>
#       <th id="T_f95cb_level0_col7" class="col_heading level0 col7" >EXTRAS</th>
#       <th id="T_f95cb_level0_col8" class="col_heading level0 col8" >DID NOT BAT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
final.sort_values('BATTER')
# Out:
#                           TEAMS             BATTER  RUNS  BALLS  4s  6s  \
# 10  Royal Challengers Bangalore     AB de Villiers    18     12   3   0
# 14  Royal Challengers Bangalore  Abhimanyu Mithun     11      8   2   0
# 4           Chennai Super Kings       Albie Morkel     2      4   0   0
# 8   Royal Challengers Bangalore        Chris Gayle     0      3   0   0
# 13  Royal Challengers Bangalore     Daniel Vettori     0      1   0   0
# 6           Chennai Super Kings       Dwayne Bravo     6      1   0   1
# 16  Royal Challengers Bangalore        JS Mohammad     2      2   0   0
# 11  Royal Challengers Bangalore    Luke Pomersbach     2      3   0   0
# 2           Chennai Super Kings           MS Dhoni    22     13   0   2
# 7   Royal Challengers Bangalore     Mayank Agarwal    10      5   2   0
# 0           Chennai Super Kings     Michael Hussey    63     45   3   3
# 1           Chennai Super Kings       Murali Vijay    95     52   4   6
# ...

# %%
final.sort_values("BATTER",ascending=False)
# Out:
#                           TEAMS             BATTER  RUNS  BALLS  4s  6s  \
# 15  Royal Challengers Bangalore        Zaheer Khan    21     21   2   0
# 9   Royal Challengers Bangalore        Virat Kohli    35     32   1   1
# 3           Chennai Super Kings       Suresh Raina     8      5   0   1
# 12  Royal Challengers Bangalore     Saurabh Tiwary    42     34   1   3
# 5           Chennai Super Kings        S Badrinath     0      0   0   0
# 1           Chennai Super Kings       Murali Vijay    95     52   4   6
# 0           Chennai Super Kings     Michael Hussey    63     45   3   3
# 7   Royal Challengers Bangalore     Mayank Agarwal    10      5   2   0
# 2           Chennai Super Kings           MS Dhoni    22     13   0   2
# 11  Royal Challengers Bangalore    Luke Pomersbach     2      3   0   0
# 16  Royal Challengers Bangalore        JS Mohammad     2      2   0   0
# 6           Chennai Super Kings       Dwayne Bravo     6      1   0   1
# ...

# %%
final['RUNS'].sum()
# Out:
# np.int64(337)

# %%
final[final.TEAMS=='Chennai Super Kings']
# Out:
#                  TEAMS          BATTER  RUNS  BALLS  4s  6s      SR  EXTRAS  \
# 0  Chennai Super Kings  Michael Hussey    63     45   3   3  140.00     9.0
# 1  Chennai Super Kings    Murali Vijay    95     52   4   6  182.69     NaN
# 2  Chennai Super Kings        MS Dhoni    22     13   0   2  169.23     NaN
# 3  Chennai Super Kings    Suresh Raina     8      5   0   1  160.00     NaN
# 4  Chennai Super Kings    Albie Morkel     2      4   0   0   50.00     NaN
# 5  Chennai Super Kings     S Badrinath     0      0   0   0    0.00     NaN
# 6  Chennai Super Kings    Dwayne Bravo     6      1   0   1  600.00     NaN
#
#            DID NOT BAT
# 0      Wriddhiman Saha
# 1  Ravichandran Ashwin
# 2        Shadab Jakati
# 3                 Doug
# 4            Bollinger
# 5                  NaN
# 6                  NaN

# %%
res=final[final.TEAMS=='Chennai Super Kings'].RUNS.sum()
res
# Out:
# np.int64(196)

# %%
final[final.TEAMS=='Royal Challengers Bangalore'].RUNS.sum()
# Out:
# np.int64(141)

# %%
final['RUNS'].value_counts()
# Out:
# RUNS
# 2     3
# 0     3
# 63    1
# 22    1
# 95    1
# 8     1
# 6     1
# 10    1
# 35    1
# 18    1
# 42    1
# 11    1
# 21    1
# Name: count, dtype: int64
